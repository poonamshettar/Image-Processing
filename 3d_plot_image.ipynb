# %%
import cv2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.axes(projection='3d')
img=cv2.imread('assignment_im.jpg')
cv2.imshow("image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(img)
x=img[:,:,0]
y=img[:,:,1]
z=img[:,:,2]
plt.axes(projection='3d')
plt.scatter(x,y,z)

# Show the 3D image plot
plt.show()
# Out:
# [[[237 237 237]
#   [237 237 237]
#   [237 237 237]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[237 237 237]
#   [237 237 237]
#   [237 237 237]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[238 238 238]
#   [238 238 238]
#   [238 238 238]
#   ...
#   [239 239 239]
#   [239 239 239]
#   [239 239 239]]
#
#  ...
#
#  [[169 170 168]
#   [169 170 168]
#   [169 170 168]
#   ...
#   [116 117 115]
#   [100 101  99]
#   [ 88  89  87]]
#
#  [[169 170 168]
#   [169 170 168]
#   [169 170 168]
#   ...
#   [113 114 112]
#   [ 96  97  95]
#   [ 82  83  81]]
#
#  [[169 170 168]
#   [169 170 168]
#   [169 170 168]
#   ...
#   [114 115 113]
#   [ 95  96  94]
#   [ 80  81  79]]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
image_2d = np.random.rand(100, 100)

# Plot the 2D image
plt.imshow(image_2d, cmap='gray')
plt.show()
x = np.arange(0, 100)
y = np.arange(0, 100)
x, y = np.meshgrid(x, y)

# The z coordinate is the intensity of the pixel
z = image_2d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='gray')

# Show the plot
plt.show()
